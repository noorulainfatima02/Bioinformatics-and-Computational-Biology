# %% [markdown]
# # 📓 Advanced Computational Biology Notebook
# **Lead Researcher:** Noor Ul Ain Fatima
# **Project:** Comparative Sequence Structure Validation

# %%
# Simulating protein mutation index
mutation_score = [1.2, 2.4, 0.8, 3.1, 1.9]
print(f'Average Computational Mutation Index: {sum(mutation_score)/len(mutation_score)}')
